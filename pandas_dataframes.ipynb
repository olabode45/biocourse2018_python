# %%
import pandas

# %%
data = pandas.read_csv('gapminder_gdp_oceania.csv')
print(data)
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 13 columns):
# country           2 non-null object
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12), object(1)
# memory usage: 288.0+ bytes
# None

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = pandas.read_csv('gapminder_gdp_oceania.csv', index_col='country')
print(data)
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
help(pandas.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
print(data.columns)
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
print(data.T)
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
transposed_data = data.T

# %%
print(transposed_data.columns)
# Out:
# Index(['Australia', 'New Zealand'], dtype='object', name='country')

# %%
print(transposed_data.index)
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
print(data.describe())
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
help(data.head)
# Out:
# Help on method head in module pandas.core.generic:
#
# head(n=5) method of pandas.core.frame.DataFrame instance
#     Return the first n rows.
#
#     Parameters
#     ----------
#     n : int, default 5
#         Number of rows to select.
#
#     Returns
#     -------
#     obj_head : type of caller
#         The first n rows of the caller object.

# %%
help(data.tail)
# Out:
# Help on method tail in module pandas.core.generic:
#
# tail(n=5) method of pandas.core.frame.DataFrame instance
#     Return the last n rows.
#
#     Parameters
#     ----------
#     n : int, default 5
#         Number of rows to select.
#
#     Returns
#     -------
#     obj_tail : type of caller
#         The last n rows of the caller object.

# %%
africa_data = pandas.read_csv('gapminder_gdp_africa.csv', index_col='country')

# %%
print(africa_data.describe())
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      1252.572466     1385.236062     1598.078825     2050.363801
# std        982.952116     1134.508918     1461.839189     2847.717603
# min        298.846212      335.997115      355.203227      412.977514
# 25%        534.990554      606.954355      673.329046      779.815648
# 50%        987.025569     1024.022987     1133.783677     1210.376379
# 75%       1454.886645     1573.040442     1702.219247     1890.112274
# max       4725.295531     5487.104219     6757.030816    18772.751690
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       52.000000       52.000000       52.000000       52.000000
# mean      2339.615674     2585.938508     2481.592960     2282.668991
# std       3286.853884     4142.398707     3242.632753     2566.531947
# ...

# %%
africa_data
# Out:
#                           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria                      2449.008185     3013.976023     2550.816880
# Angola                       3520.610273     3827.940465     4269.276742
# Benin                        1062.752200      959.601080      949.499064
# Botswana                      851.241141      918.232535      983.653976
# Burkina Faso                  543.255241      617.183465      722.512021
# Burundi                       339.296459      379.564628      355.203227
# Cameroon                     1172.667655     1313.048099     1399.607441
# Central African Republic     1071.310713     1190.844328     1193.068753
# Chad                         1178.665927     1308.495577     1389.817618
# Comoros                      1102.990936     1211.148548     1406.648278
# Congo Dem. Rep.               780.542326      905.860230      896.314634
# Congo Rep.                   2125.621418     2315.056572     2464.783157
# ...

# %%
africa_data.head(3)
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Algeria     2449.008185     3013.976023     2550.816880     3246.991771
# Angola      3520.610273     3827.940465     4269.276742     5522.776375
# Benin       1062.752200      959.601080      949.499064     1035.831411
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Algeria     4182.663766     4910.416756     5745.160213     5681.358539
# Angola      5473.288005     3008.647355     2756.953672     2430.208311
# Benin       1085.796879     1029.161251     1277.897616     1225.856010
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Algeria     5023.216647     4797.295051     5288.040382     6223.367465
# Angola      2627.845685     2277.140884     2773.287312     4797.231267
# Benin       1191.207681     1232.975292     1372.877931     1441.284873

# %%
africa_data.tail(2)
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Zambia       1147.388831     1311.956766     1452.725766     1777.077318
# Zimbabwe      406.884115      518.764268      527.272182      569.795071
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Zambia       1773.498265     1588.688299     1408.678565     1213.315116
# Zimbabwe      799.362176      685.587682      788.855041      706.157306
#
#           gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Zambia       1210.884633     1071.353818     1071.613938     1271.211593
# Zimbabwe      693.420786      792.449960      672.038623      469.709298

# %%
subset = africa_data.tail(2)
subset.to_csv('subset.csv')

# %%
africa_data.iloc[0, 1]
# Out:
# 3013.976023

# %%
africa_data.loc['Algeria', 'gdpPercap_1957']
# Out:
# 3013.976023

# %%
africa_data.iloc[0:2, 0]
# Out:
# country
# Algeria    2449.008185
# Angola     3520.610273
# Name: gdpPercap_1952, dtype: float64

# %%
type(africa_data.iloc[0:2, 0])
# Out:
# pandas.core.series.Series

# %%
africa_data.iloc[0:2, :]
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Algeria     2449.008185     3013.976023     2550.816880     3246.991771
# Angola      3520.610273     3827.940465     4269.276742     5522.776375
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Algeria     4182.663766     4910.416756     5745.160213     5681.358539
# Angola      5473.288005     3008.647355     2756.953672     2430.208311
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Algeria     5023.216647     4797.295051     5288.040382     6223.367465
# Angola      2627.845685     2277.140884     2773.287312     4797.231267

# %%
africa_data.iloc[:, 0]
# Out:
# country
# Algeria                     2449.008185
# Angola                      3520.610273
# Benin                       1062.752200
# Botswana                     851.241141
# Burkina Faso                 543.255241
# Burundi                      339.296459
# Cameroon                    1172.667655
# Central African Republic    1071.310713
# Chad                        1178.665927
# Comoros                     1102.990936
# Congo Dem. Rep.              780.542326
# Congo Rep.                  2125.621418
# Cote d'Ivoire               1388.594732
# Djibouti                    2669.529475
# Egypt                       1418.822445
# Equatorial Guinea            375.643123
# Eritrea                      328.940557
# Ethiopia                     362.146280
# Gabon                       4293.476475
# Gambia                       485.230659
# Ghana                        911.298937
# Guinea                       510.196492
# Guinea-Bissau                299.850319
# ...

# %%
type(africa_data.iloc[0:2, :])
# Out:
# pandas.core.frame.DataFrame

# %%
type(africa_data.iloc[:, 0])
# Out:
# pandas.core.series.Series

# %%
africa_data.loc['South Africa', :]
# Out:
# gdpPercap_1952    4725.295531
# gdpPercap_1957    5487.104219
# gdpPercap_1962    5768.729717
# gdpPercap_1967    7114.477971
# gdpPercap_1972    7765.962636
# gdpPercap_1977    8028.651439
# gdpPercap_1982    8568.266228
# gdpPercap_1987    7825.823398
# gdpPercap_1992    7225.069258
# gdpPercap_1997    7479.188244
# gdpPercap_2002    7710.946444
# gdpPercap_2007    9269.657808
# Name: South Africa, dtype: float64

# %%
africa_data.loc[:,'gdpPercap_2002']
# Out:
# country
# Algeria                      5288.040382
# Angola                       2773.287312
# Benin                        1372.877931
# Botswana                    11003.605080
# Burkina Faso                 1037.645221
# Burundi                       446.403513
# Cameroon                     1934.011449
# Central African Republic      738.690607
# Chad                         1156.181860
# Comoros                      1075.811558
# Congo Dem. Rep.               241.165877
# Congo Rep.                   3484.061970
# Cote d'Ivoire                1648.800823
# Djibouti                     1908.260867
# Egypt                        4754.604414
# Equatorial Guinea            7703.495900
# Eritrea                       765.350001
# Ethiopia                      530.053532
# Gabon                       12521.713920
# Gambia                        660.585600
# Ghana                        1111.984578
# Guinea                        945.583584
# Guinea-Bissau                 575.704718
# ...

# %%
africa_data.loc['Benin':'Burundi', 'gdpPercap_1957':'gdpPercap_1972']
# Out:
#               gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Benin             959.601080      949.499064     1035.831411     1085.796879
# Botswana          918.232535      983.653976     1214.709294     2263.611114
# Burkina Faso      617.183465      722.512021      794.826560      854.735976
# Burundi           379.564628      355.203227      412.977514      464.099504

# %%
subset = africa_data.loc['Benin':'Burundi', 'gdpPercap_1957':'gdpPercap_1972']

# %%
subset.describe()
# Out:
#        gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count        4.000000        4.000000        4.000000        4.000000
# mean       718.645427      752.717072      864.586195     1167.060868
# std        272.742222      289.243040      346.760204      774.753250
# min        379.564628      355.203227      412.977514      464.099504
# 25%        557.778756      630.684822      699.364298      757.076858
# 50%        767.708000      836.005542      915.328985      970.266428
# 75%        928.574671      958.037792     1080.550882     1380.250438
# max        959.601080      983.653976     1214.709294     2263.611114

# %%
subset.mean()
# Out:
# gdpPercap_1957     718.645427
# gdpPercap_1962     752.717072
# gdpPercap_1967     864.586195
# gdpPercap_1972    1167.060868
# dtype: float64

# %%
subset.max()
# Out:
# gdpPercap_1957     959.601080
# gdpPercap_1962     983.653976
# gdpPercap_1967    1214.709294
# gdpPercap_1972    2263.611114
# dtype: float64

# %%
subset.min()
# Out:
# gdpPercap_1957    379.564628
# gdpPercap_1962    355.203227
# gdpPercap_1967    412.977514
# gdpPercap_1972    464.099504
# dtype: float64

# %%
subset.std()
# Out:
# gdpPercap_1957    272.742222
# gdpPercap_1962    289.243040
# gdpPercap_1967    346.760204
# gdpPercap_1972    774.753250
# dtype: float64

# %%
subset.mean(axis=1)
# Out:
# country
# Benin           1007.682109
# Botswana        1345.051730
# Burkina Faso     747.314505
# Burundi          402.961218
# dtype: float64

# %%
subset
# Out:
#               gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Benin             959.601080      949.499064     1035.831411     1085.796879
# Botswana          918.232535      983.653976     1214.709294     2263.611114
# Burkina Faso      617.183465      722.512021      794.826560      854.735976
# Burundi           379.564628      355.203227      412.977514      464.099504

# %%
subset > 700
# Out:
#               gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Benin                   True            True            True            True
# Botswana                True            True            True            True
# Burkina Faso           False            True            True            True
# Burundi                False           False           False           False

# %%
algeria_data = africa_data.loc['Algeria', :]
zimbabwe_data = africa_data.loc['Zimbabwe', :]
two_country_data = pandas.concat([algeria_data, zimbabwe_data], axis=1)

# %%
two_country_data.T
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# Algeria      2449.008185     3013.976023     2550.816880     3246.991771
# Zimbabwe      406.884115      518.764268      527.272182      569.795071
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# Algeria      4182.663766     4910.416756     5745.160213     5681.358539
# Zimbabwe      799.362176      685.587682      788.855041      706.157306
#
#           gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# Algeria      5023.216647     4797.295051     5288.040382     6223.367465
# Zimbabwe      693.420786      792.449960      672.038623      469.709298

# %%
subset[subset > 700]
# Out:
#               gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Benin             959.601080      949.499064     1035.831411     1085.796879
# Botswana          918.232535      983.653976     1214.709294     2263.611114
# Burkina Faso             NaN      722.512021      794.826560      854.735976
# Burundi                  NaN             NaN             NaN             NaN

# %%
africa_data[africa_data.index.isin(['Algeria', 'Zimbabwe'])]
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Algeria      2449.008185     3013.976023     2550.816880     3246.991771
# Zimbabwe      406.884115      518.764268      527.272182      569.795071
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Algeria      4182.663766     4910.416756     5745.160213     5681.358539
# Zimbabwe      799.362176      685.587682      788.855041      706.157306
#
#           gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Algeria      5023.216647     4797.295051     5288.040382     6223.367465
# Zimbabwe      693.420786      792.449960      672.038623      469.709298

# %%
filtered_subset = subset[subset > 700]

# %%
filtered_subset.describe()
# Out:
#        gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count        2.000000        3.000000        3.000000        3.000000
# mean       938.916808      885.221687     1015.122422     1401.381323
# std         29.251979      141.941770      210.706014      755.597409
# min        918.232535      722.512021      794.826560      854.735976
# 25%        928.574671      836.005542      915.328985      970.266428
# 50%        938.916808      949.499064     1035.831411     1085.796879
# 75%        949.258944      966.576520     1125.270352     1674.703997
# max        959.601080      983.653976     1214.709294     2263.611114

# %%
filtered_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Benin to Burundi
# Data columns (total 4 columns):
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    3 non-null float64
# gdpPercap_1967    3 non-null float64
# gdpPercap_1972    3 non-null float64
# dtypes: float64(4)
# memory usage: 320.0+ bytes

# %%
subset > 700
# Out:
#               gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Benin                   True            True            True            True
# Botswana                True            True            True            True
# Burkina Faso           False            True            True            True
# Burundi                False           False           False           False

# %%
subset > subset.mean()
# Out:
#               gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Benin                   True            True            True           False
# Botswana                True            True            True            True
# Burkina Faso           False           False           False           False
# Burundi                False           False           False           False

# %%
subset.aggregate('sum')
# Out:
# gdpPercap_1957    2874.581708
# gdpPercap_1962    3010.868288
# gdpPercap_1967    3458.344778
# gdpPercap_1972    4668.243473
# dtype: float64

# %%
subset > africa_data.loc[:,'gdpPercap_1952':'gdpPercap_1972'].mean() / 2
# Out:
#               gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Benin                  False            True            True            True
# Botswana               False            True            True            True
# Burkina Faso           False           False           False           False
# Burundi                False           False           False           False
#
#               gdpPercap_1972
# country
# Benin                  False
# Botswana                True
# Burkina Faso           False
# Burundi                False

# %%
mask2 = subset > africa_data.loc[:,'gdpPercap_1952':'gdpPercap_1972'].mean() / 2
mask2
# Out:
#               gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Benin                  False            True            True            True
# Botswana               False            True            True            True
# Burkina Faso           False           False           False           False
# Burundi                False           False           False           False
#
#               gdpPercap_1972
# country
# Benin                  False
# Botswana                True
# Burkina Faso           False
# Burundi                False

# %%
mask2.aggregate('sum')
# Out:
# gdpPercap_1952    0
# gdpPercap_1957    2
# gdpPercap_1962    2
# gdpPercap_1967    2
# gdpPercap_1972    1
# dtype: int64

# %%
sum([1, 2, 3])
# Out:
# 6

# %%
sum([True, True, False])
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
mask2.aggregate('sum', axis=1)
# Out:
# country
# Benin           3
# Botswana        4
# Burkina Faso    0
# Burundi         0
# dtype: int64

# %%
mask2.T.aggregate('sum')
# Out:
# country
# Benin           3
# Botswana        4
# Burkina Faso    0
# Burundi         0
# dtype: int64

# %%
mask2.aggregate(sum)
# Out:
# gdpPercap_1952    0
# gdpPercap_1957    2
# gdpPercap_1962    2
# gdpPercap_1967    2
# gdpPercap_1972    1
# dtype: int64

# %%
# %load_ext rpy2.ipython

# %%
# %%R -i subset
# subset
# Out:
#              gdpPercap_1957 gdpPercap_1962 gdpPercap_1967 gdpPercap_1972
# Benin              959.6011       949.4991      1035.8314      1085.7969
# Botswana           918.2325       983.6540      1214.7093      2263.6111
# Burkina Faso       617.1835       722.5120       794.8266       854.7360
# Burundi            379.5646       355.2032       412.9775       464.0995
