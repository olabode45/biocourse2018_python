# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### The next section is...
# A blah

# %%
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

# if you assign return values
# of plot functions to variables
# then you don't see them
# displayed by the Notebook
# but you do still see the plot
plot = plt.plot(time, position)
xlabel = plt.xlabel('Time (hr)')
ylabel = plt.ylabel('Position (km)')

# %%
time2 = [0, 1, 2, 3]
position2 = [300, 200, 100, 0]

plt.plot(time2, position2)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
# Out:
# Text(0,0.5,'Position (km)')

# %%
# illustrating a common syntax
# error with mismatched brackets
# where it shows the error in a
# misleading place
print("Hello class")
print("I hope you enjoy Python"
print("It sometimes can be tricky")
# Out:
#   File "<ipython-input-60-e7a429b409bc>", line 7
#     print("It sometimes can be tricky")
#         ^
# SyntaxError: invalid syntax

# %%
import pandas

data = pandas.read_csv('gapminder_gdp_oceania.csv', 
                       index_col='country')
australia_data = data.loc['Australia', :]
australia_data
# Out:
# gdpPercap_1952    10039.59564
# gdpPercap_1957    10949.64959
# gdpPercap_1962    12217.22686
# gdpPercap_1967    14526.12465
# gdpPercap_1972    16788.62948
# gdpPercap_1977    18334.19751
# gdpPercap_1982    19477.00928
# gdpPercap_1987    21888.88903
# gdpPercap_1992    23424.76683
# gdpPercap_1997    26997.93657
# gdpPercap_2002    30687.75473
# gdpPercap_2007    34435.36744
# Name: Australia, dtype: float64

# %%
australia_data.plot()
plt.xlabel('Years')
plt.ylabel('GDP per capita')
# Out:
# Text(0,0.5,'GDP per capita')

# %%
data.T.plot()
plt.ylabel('GDP per capita')
# Out:
# Text(0,0.5,'GDP per capita')

# %%
data.T.plot(kind='bar')

# %%
data.T.plot(kind='barh')

# %%
# not appropriate for the data - it adds the data
# together to get "total area under graph"
data.T.plot(kind='area')

# %%
plt.style.use('ggplot')
data.T.plot(kind='bar')
plt.ylabel('GDP per capita')
plt.xticks(rotation=90)
plt.yticks(rotation=45)
plt.savefig('plot.svg')

# %%
pwd
# Out:
# '/home/pvh/data'

# %%
cd ..
# Out:
# /home/pvh

# %%
cd data/
# Out:
# /home/pvh/data

# %%
years_list = []
# print(data.columns)
for column_name in data.columns:
#     print(column_name, type(column_name))
    year = column_name[10:]
#     year = column_name[-4:]
#     print(year, type(year))
    years_list.append(year)
# print(years_list)

australia_gdp_list = data.loc['Australia', :].tolist()
# print(australia_gdp_list)

plt.plot(years_list, australia_gdp_list, 'y-.')
plt.xlabel('Year')
plt.xticks(rotation=90)
plt.ylabel('GDP per capita')
# Out:
# Text(0,0.5,'GDP per capita')

# %%
years_list = []  # accumulator variable
# print(data.columns)
for column_name in data.columns:
#     print(column_name, type(column_name))
    year = column_name[10:]
#     year = column_name[-4:]
#     print(year, type(year))
    years_list.append(year)
# print(years_list)

australia_gdp_list = data.loc['Australia', :].tolist()
nz_gdp_list = data.loc['New Zealand', :].tolist()
# print(australia_gdp_list)

plt.plot(years_list, australia_gdp_list, 'r-.')
plt.plot(years_list, nz_gdp_list, 'b-')
plt.xlabel('Year')
plt.xticks(rotation=90)
plt.ylabel('GDP per capita')
# Out:
# Text(0,0.5,'GDP per capita')

# %%
years_list = []  # accumulator variable
# print(data.columns)
for column_name in data.columns:
#     print(column_name, type(column_name))
    year = column_name[10:]
#     year = column_name[-4:]
#     print(year, type(year))
    years_list.append(year)
# print(years_list)

data2 = data.copy()
data2.columns =  years_list

# %%
plt.scatter(australia_gdp_list, nz_gdp_list)
plt.xlabel('Australia')
plt.ylabel('New Zealand')
# Out:
# Text(0,0.5,'New Zealand')

# %%
data.T.plot.scatter(x = 'Australia', y = 'New Zealand')

# %%
europe_data = pandas.read_csv('gapminder_gdp_europe.csv',
                             index_col='country')
europe_data.T.plot.scatter(x='Germany', y='Italy')

# %%
europe_data.T.plot()

# %%
europe_data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       30.000000       30.000000       30.000000       30.000000
# mean      5661.057435     6963.012816     8365.486814    10143.823757
# std       3114.060493     3677.950146     4199.193906     4724.983889
# min        973.533195     1353.989176     1709.683679     2172.352423
# 25%       3241.132406     4394.874315     5373.536612     6657.939047
# 50%       5142.469716     6066.721495     7515.733738     9366.067033
# 75%       7236.794919     9597.220820    10931.085347    13277.182057
# max      14734.232750    17909.489730    20431.092700    22966.144320
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       30.000000       30.000000       30.000000       30.000000
# mean     12479.575246    14283.979110    15617.896551    17214.310727
# std       5509.691411     5874.464896     6453.234827     7482.957960
# ...

# %%
europe_data.min()
# Out:
# gdpPercap_1952     973.533195
# gdpPercap_1957    1353.989176
# gdpPercap_1962    1709.683679
# gdpPercap_1967    2172.352423
# gdpPercap_1972    2860.169750
# gdpPercap_1977    3528.481305
# gdpPercap_1982    3630.880722
# gdpPercap_1987    3738.932735
# gdpPercap_1992    2497.437901
# gdpPercap_1997    3193.054604
# gdpPercap_2002    4604.211737
# gdpPercap_2007    5937.029526
# dtype: float64

# %%
europe_data.min().plot(label='min')
europe_data.mean().plot(label='mean')
europe_data.max().plot(label='max')
plt.legend(loc='best')

# %%
plt.savefig('linegraph.eps')
